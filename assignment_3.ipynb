# %% [markdown]
# # Selenium

# %%
from selenium import webdriver
from chromedriver_autoinstaller import install
install(True)
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait

from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.common.exceptions import ElementNotInteractableException

import time, re
import pandas as pd

# %%
driver = webdriver.Chrome()
driver.get("https://news.google.com/")
driver.implicitly_wait(0.5)

try:
    proceed_to_webpage_button = driver.find_element(By.XPATH, "//*[@id='yDmH0d']/c-wiz/div/div/div/div[2]/div[1]/div[3]/div[1]/div[1]/form[1]")
    proceed_to_webpage_button.click()
except:
    pass

# %%
links = driver.find_elements(By.CSS_SELECTOR, ".EctEBd a")
if links:
    print(len(links))
    for link in links:
        print(link.text, link.get_attribute("href"))
# Out:
# 13
# Home https://news.google.com/home?hl=en-US&gl=US&ceid=US%3Aen
# For you None
# Following None
# News Showcase https://news.google.com/showcase?hl=en-US&gl=US&ceid=US%3Aen
# U.S. https://news.google.com/topics/CAAqIggKIhxDQkFTRHdvSkwyMHZNRGxqTjNjd0VnSmxiaWdBUAE?hl=en-US&gl=US&ceid=US%3Aen
# World https://news.google.com/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRGx1YlY4U0FtVnVHZ0pWVXlnQVAB?hl=en-US&gl=US&ceid=US%3Aen
# Local https://news.google.com/topics/CAAqHAgKIhZDQklTQ2pvSWJHOWpZV3hmZGpJb0FBUAE?hl=en-US&gl=US&ceid=US%3Aen
# Business https://news.google.com/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRGx6TVdZU0FtVnVHZ0pWVXlnQVAB?hl=en-US&gl=US&ceid=US%3Aen
# Technology https://news.google.com/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRGRqTVhZU0FtVnVHZ0pWVXlnQVAB?hl=en-US&gl=US&ceid=US%3Aen
# Entertainment https://news.google.com/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNREpxYW5RU0FtVnVHZ0pWVXlnQVAB?hl=en-US&gl=US&ceid=US%3Aen
# Sports https://news.google.com/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRFp1ZEdvU0FtVnVHZ0pWVXlnQVAB?hl=en-US&gl=US&ceid=US%3Aen
# Science https://news.google.com/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRFp0Y1RjU0FtVnVHZ0pWVXlnQVAB?hl=en-US&gl=US&ceid=US%3Aen
# Health https://news.google.com/topics/CAAqIQgKIhtDQkFTRGdvSUwyMHZNR3QwTlRFU0FtVnVLQUFQAQ?hl=en-US&gl=US&ceid=US%3Aen

# %%
try:
    topic = driver.find_element(By.XPATH, "//*[@id='gb']/div[3]/div/c-wiz/div[1]/div[6]/a")
    topic.click()
except:
    topic = driver.find_element(By.XPATH, "//*[@id='gb']/div[3]/div/c-wiz/div[1]/div[5]")
    driver.execute_script("arguemnts[0].scrollIntoView({block: 'center'));", topic)
    driver.exectue_script("arguments[0].click();", topic)

wait = WebDriverWait(driver, 10)
wait.until(EC.url_contains("/topics/CAAqIggKIhxDQkFTRHdvSkwyMHZNRGxqTjNjd0VnSmxiaWdBUAE?hl=en-US&gl=US&ceid=US%3Aen"))
print(driver.current_url)

time.sleep(10)
# Out:
# https://news.google.com/topics/CAAqIggKIhxDQkFTRHdvSkwyMHZNRGxqTjNjd0VnSmxiaWdBUAE?hl=en-US&gl=US&ceid=US%3Aen

# %%
article_count = len(driver.find_elements(By.CSS_SELECTOR, ".IBr9hb"))

data = []
for i in range(article_count):
    article = driver.find_elements(By.CSS_SELECTOR, ".IBr9hb")[i]
    link = article.find_element(By.TAG_NAME, "a")
    href = link.get_attribute("href")
    time.sleep(2)
    source = article.find_element(By.CSS_SELECTOR, ".vr1PYe")
    
    try:
        title = article.find_element(By.CSS_SELECTOR, ".IBr9hb .gPFEn")
    except:
        pass
    
    title_text = title.text
    news_source = source.text

    data.append({
        "title": title_text,
        "link": href,
        "news_source": news_source
    })

df = pd.DataFrame(data)
df
# Out:
#                                                 title  \
# 0
# 1
# 2   Second Strike Scrutiny Obscures Larger Questio...
# 3   Judges lash out at Justice Department for stil...
# 4   Who is the Jan. 6 pipe bomb suspect? And, lawm...
# 5   Trump ventures deeper into anti-immigrant lang...
# 6   Trump administration says Europe faces 'civili...
# 7   Mike Johnson scrambles to pass Pentagon bill a...
# 8   Homeland security head reveals plans to widen ...
# 9   Trump fired this regulator. She’s fighting him...
# 10  Takeaways From the Pentagon Investigation on H...
# 11  Supreme Court allows Texas GOP to use new redi...
# 12  Video shows Luigi Mangione says he didn't want...
# 13  Centrist lawmakers unveil ACA plan amid House,...
# 14  D.C. may see accumulating snow as storm hits M...
# 15  Trump hires new architect for White House ball...
# 16  ‘It’s attempted kidnapping’: Video shows maske...
# 17  Democrats eye a red-state push even as intrapa...
# 18  Signing of the Washington Accords for Peace an...
# 19  Brian Walshe murder trial: Man who had affair ...
# 20  Triple polar vortex to plunge central and east...
# 21  HONORING THE MEMORY OF SPECIALIST SARAH BECKST...
# 22  National Guard can stay in D.C. for now, appea...
# 23  Putin says there are points he can't agree to ...
# 24  U.S. tightens immigration work permits in late...
# 25  European Leaders Warn Zelensky to Be Wary in U...
# 26  ‘There is no Mamdani effect’: Manhattan luxury...
# 27  Florida House barrels ahead on redistricting d...
# 28  Putin says there are points in the U.S. propos...
# 29  Federal judge blocks imminent State Dept layof...
# 30  Trump’s Approval Rating Dips as Views of His H...
# 31  Flags fly at half-staff in Colorado on Thursda...
# 32  Appeasing the administration hasn’t worked. Th...
# 33  Examining Trump's Pardon of Former Honduran Pr...
# 34  JD Vance says his marriage with Usha is 'as st...
# 35  Halle Berry declares Gavin Newsom 'should not ...
# 36  Family of woman who went missing in Northern C...
# 37  Trump Returns Coast Guard Helicopter to Oregon...
#
#                                                  link  \
# 0   https://news.google.com/read/CBMiwwFBVV95cUxOW...
# 1   https://news.google.com/read/CBMiWkFVX3lxTE9OT...
# 2   https://news.google.com/read/CBMihgFBVV95cUxPN...
# 3   https://news.google.com/read/CBMiqgFBVV95cUxNT...
# 4   https://news.google.com/read/CBMiwwFBVV95cUxOW...
# 5   https://news.google.com/read/CBMirAFBVV95cUxQW...
# 6   https://news.google.com/read/CBMiWkFVX3lxTE9OT...
# 7   https://news.google.com/read/CBMiiAFBVV95cUxPe...
# 8   https://news.google.com/read/CBMiekFVX3lxTFBiS...
# 9   https://news.google.com/read/CBMirAFBVV95cUxPN...
